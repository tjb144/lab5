# %%
name = str(input("Enter a name\n"))
age = int(input("Enter the age\n"))
print("The age of " + name + " is " + str(age) + ".")
# Out:
# Enter a name
# Tom
# Enter the age
# 23
# The age of Tom is 23.
